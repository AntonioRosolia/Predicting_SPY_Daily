# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pickle
import calendar
import matplotlib.dates as mdates

from scipy.ndimage.interpolation import shift
from statsmodels.graphics.tsaplots import plot_acf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
df_prices = pd.read_pickle("D:/all_data.pickle")

Future = df_prices["Mid"]
Index = df_prices["Close"]
Future.name = "Future"
Index.name = "Index"

# %%
fig = plt.figure(figsize=(16,9))
Future.plot()
Index.plot()
plt.legend(loc='lower right')

# %%
diff = Future - Index
diff.name = "Difference Future/Index"
fig = plt.figure(figsize=(16,9))
sns.distplot(diff)

# %%
fig = plt.figure(figsize=(16,9))
sns.scatterplot(Index, Future)

# %%
fig = plt.figure(figsize=(16,9))
plt.plot(diff)

# %%
fig = plt.figure(figsize=(16,9))
(Future-Future.shift(-1)).plot()

# %%
fig = plt.figure(figsize=(16,9))
(Index-Index.shift(-1)).plot()

# %%
fig = plt.figure(figsize=(16,9))
(Index-Index.shift(-1)).plot(kind="hist")

# %%
fig = plt.figure(figsize=(16,9))
(Future-Future.shift(-1)).plot(kind="hist")

# %%
Future.rolling(200).corr(Index).plot(figsize=(16,9))

# %%
df_prices["500.0P_NBid"].plot(kind="hist")

# %%
df_prices["800.0P_NAsk"].plot(kind="hist")
